# %% [markdown]
# # Setup `gym_classics2`
#
# This is a patched version of `gym_classic` originally by Brett Delay which we will use in class. Run the following code using your python environment to install the package.

# %%
# !git clone https://github.com/mhahsler/gym-classics2.git
# !cd gym-classics2; git pull
# !cd gym-classics2; pip install -e .
# Out:
# fatal: destination path 'gym-classics2' already exists and is not an empty directory.
# Already up to date.
# Obtaining file:///home/mhahsler/github/Introduction_to_Reinforcement_Learning/common/gym-classics2
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for gym-classics2 (pyproject.toml) ... done
#   Created wheel for gym-classics2: filename=gym_classics2-1.0.0-0.editable-py3-none-any.whl size=16662 sha256=db7b2945cd2f564860948be48fdd155d86b872598a3a0be538e33f9a2ea11069
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vc9xl2oq/wheels/13/ce/d3/cd507c5e4b8fc8f76c5f5ad11d7eac9114dc2e820fc550054f
# Successfully built gym-classics2
# ...
#   Attempting uninstall: gym-classics2
#     Found existing installation: gym-classics2 1.0.0
#     Uninstalling gym-classics2-1.0.0:
# ...
