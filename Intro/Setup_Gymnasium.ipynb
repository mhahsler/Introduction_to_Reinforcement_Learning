# %% [markdown]
# # Setup Gymnasium
#
# The documentation for Gymnasium is available at https://gymnasium.farama.org/
#
# Steps:
# 1. Create a new folder and open it with VS Code and install all needed Python Extensions in VS Code.
# 2. Create a new virtual environment (CTRL-Shift P Python Create Environment...)
# 3. I needed to install swig and the Python C++ headers on WSL2 via the terminal
#     * `sudo apt install swig`
#     * `sudo apt-get install python3-dev`
# 4. Install python libraries for gymnasium with the needed extras

# %%
# %pip install swig
# %pip install gymnasium[box2d,classic_control]
# Out:
# Collecting swig
#   Using cached swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Using cached swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
# Installing collected packages: swig
# Successfully installed swig-4.4.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting gymnasium[box2d,classic_control]
#   Downloading gymnasium-1.2.3-py3-none-any.whl.metadata (10 kB)
# Collecting numpy>=1.21.0 (from gymnasium[box2d,classic_control])
#   Downloading numpy-2.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting cloudpickle>=1.2.0 (from gymnasium[box2d,classic_control])
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting typing-extensions>=4.3.0 (from gymnasium[box2d,classic_control])
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting farama-notifications>=0.0.1 (from gymnasium[box2d,classic_control])
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting box2d==2.3.10 (from gymnasium[box2d,classic_control])
#   Downloading Box2D-2.3.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (573 bytes)
# Collecting pygame>=2.1.3 (from gymnasium[box2d,classic_control])
#   Using cached pygame-2.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: swig==4.* in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[box2d,classic_control]) (4.4.1)
# Downloading gymnasium-1.2.3-py3-none-any.whl (952 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 22.1 MB/s  0:00:00
# Downloading Box2D-2.3.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 38.6 MB/s  0:00:00
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading numpy-2.4.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 37.1 MB/s  0:00:00m0:00:0100:01
# Using cached pygame-2.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: farama-notifications, box2d, typing-extensions, pygame, numpy, cloudpickle, gymnasium
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [gymnasium]/7 [gymnasium]
# Successfully installed box2d-2.3.10 cloudpickle-3.1.2 farama-notifications-0.0.4 gymnasium-1.2.3 numpy-2.4.0 pygame-2.6.1 typing-extensions-4.15.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Capturing Environment Visualizations in Notebooks
#
# Additional installs for screen capturing so environment visualizations can be converted to embedded videos.
# This also works on Google Colab so you can see the visualization.
#
# For recording videos, I had to install on WSL2:
#
# * `sudo apt-get install xvfb ffmpeg`

# %% [markdown]
# Additional python packages for screen capturing.

# %%
# %pip install pyvirtualdisplay
# %pip install gymnasium[other]
# Out:
# Collecting pyvirtualdisplay
#   Using cached PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Using cached PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gymnasium[other] in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[other]) (2.4.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[other]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[other]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from gymnasium[other]) (0.0.4)
# Collecting moviepy>=1.0.0 (from gymnasium[other])
#   Using cached moviepy-2.2.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting matplotlib>=3.0 (from gymnasium[other])
#   Using cached matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting opencv-python>=3.0 (from gymnasium[other])
#   Using cached opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting seaborn>=0.13 (from gymnasium[other])
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib>=3.0->gymnasium[other])
#   Using cached contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib>=3.0->gymnasium[other])
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib>=3.0->gymnasium[other])
#   Using cached fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib>=3.0->gymnasium[other])
#   Using cached kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[other]) (25.0)
# Collecting pillow>=8 (from matplotlib>=3.0->gymnasium[other])
#   Downloading pillow-12.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib>=3.0->gymnasium[other])
#   Downloading pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from matplotlib>=3.0->gymnasium[other]) (2.9.0.post0)
# Requirement already satisfied: decorator<6.0,>=4.0.2 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from moviepy>=1.0.0->gymnasium[other]) (5.2.1)
# Collecting imageio<3.0,>=2.5 (from moviepy>=1.0.0->gymnasium[other])
#   Using cached imageio-2.37.2-py3-none-any.whl.metadata (9.7 kB)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy>=1.0.0->gymnasium[other])
#   Using cached imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting proglog<=1.0.0 (from moviepy>=1.0.0->gymnasium[other])
#   Using cached proglog-0.1.12-py3-none-any.whl.metadata (794 bytes)
# Collecting python-dotenv>=0.10 (from moviepy>=1.0.0->gymnasium[other])
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting pillow>=8 (from matplotlib>=3.0->gymnasium[other])
#   Using cached pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Collecting tqdm (from proglog<=1.0.0->moviepy>=1.0.0->gymnasium[other])
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting numpy>=1.21.0 (from gymnasium[other])
#   Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: six>=1.5 in /home/mhahsler/github/Introduction_to_Reinforcement_Learning/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.0->gymnasium[other]) (1.17.0)
# Collecting pandas>=1.2 (from seaborn>=0.13->gymnasium[other])
#   Using cached pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting pytz>=2020.1 (from pandas>=1.2->seaborn>=0.13->gymnasium[other])
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.2->seaborn>=0.13->gymnasium[other])
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Using cached matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
# Using cached contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (5.0 MB)
# Using cached kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
# Using cached moviepy-2.2.1-py3-none-any.whl (129 kB)
# Using cached imageio-2.37.2-py3-none-any.whl (317 kB)
# Using cached pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
# Using cached proglog-0.1.12-py3-none-any.whl (6.3 kB)
# Using cached imageio_ffmpeg-0.6.0-py3-none-manylinux2014_x86_64.whl (29.5 MB)
# Using cached opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
# Using cached numpy-2.2.6-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.5 MB)
# Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: pytz, tzdata, tqdm, python-dotenv, pyparsing, pillow, numpy, kiwisolver, imageio_ffmpeg, fonttools, cycler, proglog, pandas, opencv-python, imageio, contourpy, moviepy, matplotlib, seaborn
#   Attempting uninstall: numpy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/19 [pillow]
#     Found existing installation: numpy 2.4.0━━━━━━━━━━━━━━━━━━  5/19 [pillow]
#     Uninstalling numpy-2.4.0:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/19 [pillow]
#       Successfully uninstalled numpy-2.4.0━━━━━━━━━━━━━━━━━━━━  5/19 [pillow]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19/19 [seaborn]8/19 [seaborn]ib]on]]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 imageio-2.37.2 imageio_ffmpeg-0.6.0 kiwisolver-1.4.9 matplotlib-3.10.8 moviepy-2.2.1 numpy-2.2.6 opencv-python-4.12.0.88 pandas-2.3.3 pillow-11.3.0 proglog-0.1.12 pyparsing-3.3.1 python-dotenv-1.2.1 pytz-2025.2 seaborn-0.13.2 tqdm-4.67.1 tzdata-2025.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# &copy; 2025 [Michael Hahsler](http://michael.hahsler.net).
# This work is openly licensed under [Creative Commons Attribution-ShareAlike 4.0 International (CC BY-SA 4.0) License](https://creativecommons.org/licenses/by-sa/4.0/)
#
# ![CC BY-SA 4.0](https://licensebuttons.net/l/by-sa/3.0/88x31.png)
